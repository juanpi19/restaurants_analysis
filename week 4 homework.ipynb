# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_file = pd.read_csv('assignment.csv')
df_file
# Out:
#           location         day  number of orders  percentage of deliveries
# 0      Bryant Park  2018-01-01               394                  0.000000
# 1      Bryant Park  2018-01-02               807                  0.000000
# 2      Bryant Park  2018-01-03               744                  0.000000
# 3      Bryant Park  2018-01-04               791                  0.000000
# 4      Bryant Park  2018-01-05               677                  0.000000
# ...            ...         ...               ...                       ...
# 2801  Williamsburg  2018-12-27               928                  0.095905
# 2802  Williamsburg  2018-12-28               948                  0.113924
# 2803  Williamsburg  2018-12-29               993                  0.094663
# 2804  Williamsburg  2018-12-30               949                  0.112750
# 2805  Williamsburg  2018-12-31               931                  0.110634
#
# [2806 rows x 4 columns]

# %%
# rename the columns
df_file = df_file.rename(columns = {'location': 'RESTAURANT_NAME', 'day': 'DATE', 'number of orders': 'NUM_ORDERS', 'percentage of deliveries': "PERC_DELIVERY"})
df_file.head()
# Out:
#   RESTAURANT_NAME        DATE  NUM_ORDERS  PERC_DELIVERY
# 0     Bryant Park  2018-01-01         394            0.0
# 1     Bryant Park  2018-01-02         807            0.0
# 2     Bryant Park  2018-01-03         744            0.0
# 3     Bryant Park  2018-01-04         791            0.0
# 4     Bryant Park  2018-01-05         677            0.0

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2806 entries, 0 to 2805
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RESTAURANT_NAME  2806 non-null   object
#  1   DATE             2806 non-null   object
#  2   NUM_ORDERS       2806 non-null   int64
#  3   PERC_DELIVERY    2806 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 87.8+ KB

# %%
df_file.DATE = pd.to_datetime(df_file.DATE)

# %%
df_file.RESTAURANT_NAME.value_counts()
# Out:
# Columbia           365
# Flatiron           365
# Williamsburg       365
# Upper West Side    365
# Midtown            365
# NYU                365
# Upper East Side    355
# Bryant Park        261
# Name: RESTAURANT_NAME, dtype: int64

# %%
df_file[df_file.RESTAURANT_NAME == 'Bryant Park'].DATE.dt.weekday.value_counts()
# Out:
# 0    53
# 4    52
# 3    52
# 2    52
# 1    52
# Name: DATE, dtype: int64

# %%
df_file.NUM_ORDERS.describe()
df_file.NUM_ORDERS.hist(bins = 30)

# %%
df_file[df_file.NUM_ORDERS == df_file.NUM_ORDERS.max()]
# Out:
#      RESTAURANT_NAME       DATE  NUM_ORDERS  PERC_DELIVERY
# 1530             NYU 2018-06-24        1385       0.080866

# %%
df_file[df_file.NUM_ORDERS > 1000].RESTAURANT_NAME.value_counts().plot(kind='bar')

# %%
df_file[df_file.NUM_ORDERS < 600].RESTAURANT_NAME.value_counts().plot(kind='bar')

# %%
# plot summer sales for each restaurant
restaurants = ['Bryant Park' , 'Columbia', 'Flatiron', 'Midtown', 'NYU', 'Upper East Side', 'Upper West Side', 'Williamsburg']

for r in restaurants:
    df_file[(df_file.DATE >= '2018-05-01') & 
               (df_file.DATE <= '2018-08-30') & 
                   (df_file.RESTAURANT_NAME == r)].plot(x = 'DATE', y = 'NUM_ORDERS', title = r)

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2806 entries, 0 to 2805
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RESTAURANT_NAME  2806 non-null   object
#  1   DATE             2806 non-null   datetime64[ns]
#  2   NUM_ORDERS       2806 non-null   int64
#  3   PERC_DELIVERY    2806 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 87.8+ KB
